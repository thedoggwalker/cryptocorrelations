# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np

ticker = ["BTC-USD", "ETH-USD", "ADA-USD", "XRP-USD", "SOL-USD", "DOGE-USD","TRX-USD","AVAX-USD","MATIC-USD","LTC-USD","UNI-USD","NEAR-USD","LINK-USD"]

crypto = yf.download(ticker, start = "2021-06-06", end = "2022-06-06")

crypto.to_csv("crypto.csv")

crypto = pd.read_csv("crypto.csv", header = [0,1], index_col = [0], parse_dates = [0])

close = crypto.loc[:,"Close"].copy()

norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
# [*********************100%***********************]  13 of 13 completed
#                ADA-USD    AVAX-USD     BTC-USD    DOGE-USD     ETH-USD  \
# Date
# 2021-06-06  100.000000  100.000000  100.000000  100.000000  100.000000
# 2021-06-07   93.198737   89.210011   93.581932   89.038130   95.402382
# 2021-06-08   94.624271   85.453139   93.336343   88.133625   92.720173
# 2021-06-09   96.816794   88.429850  104.134534   92.341188   96.065487
# 2021-06-10   91.277152   81.473092  102.342897   87.774297   91.028880
# ...                ...         ...         ...         ...         ...
# 2022-06-02   35.024323  141.822574   84.956685   22.262087   67.553880
# 2022-06-03   33.347752  132.214344   82.828835   21.635417   65.378194
# 2022-06-04   33.729758  140.989506   83.187214   21.994475   66.355357
# 2022-06-05   33.790593  138.873733   83.392856   21.847087   66.487782
# 2022-06-06   36.307385  149.358779   87.475156   22.196999   68.479784
#
# ...

# %%
# %matplotlib inline
plt.style.use("seaborn")

# %%
norm.plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize= 13)
plt.show()

# %%
ret = close.pct_change().dropna()
ret
# Out:
#              ADA-USD  AVAX-USD   BTC-USD  DOGE-USD   ETH-USD  LINK-USD  \
# Date
# 2021-06-07 -0.068013 -0.107900 -0.064181 -0.109619 -0.045976 -0.109771
# 2021-06-08  0.015296 -0.042113 -0.002624 -0.010159 -0.028115 -0.014364
# 2021-06-09  0.023171  0.034834  0.115691  0.047741  0.036080  0.057681
# 2021-06-10 -0.057218 -0.078670 -0.017205 -0.049457 -0.052429 -0.096548
# 2021-06-11 -0.062329 -0.053429  0.017214 -0.021425 -0.047643 -0.070202
# ...              ...       ...       ...       ...       ...       ...
# 2022-06-02  0.063401  0.036838  0.022430  0.021171  0.005802  0.039643
# 2022-06-03 -0.047869 -0.067748 -0.025046 -0.028150 -0.032207 -0.047017
# 2022-06-04  0.011455  0.066371  0.004327  0.016596  0.014946  0.077765
# 2022-06-05  0.001804 -0.015007  0.002472 -0.006701  0.001996  0.032571
# 2022-06-06  0.074482  0.075501  0.048953  0.016016  0.029960  0.043126
#
#              LTC-USD  MATIC-USD  NEAR-USD   SOL-USD   TRX-USD   UNI-USD  \
# Date
# ...

# %%
ret.describe()
# Out:
#           ADA-USD    AVAX-USD     BTC-USD    DOGE-USD     ETH-USD    LINK-USD  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  365.000000
# mean    -0.001363    0.003720    0.000277   -0.002504   -0.000108   -0.001728
# std      0.053229    0.072514    0.035923    0.056230    0.042971    0.057264
# min     -0.184690   -0.305147   -0.112655   -0.363863   -0.159332   -0.198355
# 25%     -0.032868   -0.040800   -0.021089   -0.030315   -0.025563   -0.035445
# 50%     -0.001897    0.005314    0.002078   -0.002454    0.002457    0.003222
# 75%      0.024413    0.041569    0.021169    0.021345    0.027799    0.030639
# max      0.184873    0.279133    0.145412    0.271892    0.116810    0.153527
#
#           LTC-USD   MATIC-USD    NEAR-USD     SOL-USD     TRX-USD     UNI-USD  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  365.000000
# mean    -0.001602   -0.000426    0.004709    0.002067    0.001214    0.032224
# ...

# %%
summary = ret.describe().T.loc[:, ["mean","std"]] # 'T' allows us to transpose and 'loc' allows us to pick columns
summary

summary ["mean"] = summary["mean"]*252
summary ["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#                mean       std
# ADA-USD   -0.343547  0.844990
# AVAX-USD   0.937464  1.151117
# BTC-USD    0.069866  0.570254
# DOGE-USD  -0.631037  0.892623
# ETH-USD   -0.027142  0.682148
# LINK-USD  -0.435365  0.909042
# LTC-USD   -0.403680  0.756936
# MATIC-USD -0.107260  1.030206
# NEAR-USD   1.186575  1.295608
# SOL-USD    0.520953  1.019352
# TRX-USD    0.305879  0.733554
# UNI-USD    8.120470  6.209238
# XRP-USD   -0.267386  0.799435

# %%
ret.corr()
# Out:
#             ADA-USD  AVAX-USD   BTC-USD  DOGE-USD   ETH-USD  LINK-USD  \
# ADA-USD    1.000000  0.605436  0.715096  0.652918  0.743723  0.736736
# AVAX-USD   0.605436  1.000000  0.586385  0.520217  0.624863  0.593451
# BTC-USD    0.715096  0.586385  1.000000  0.682110  0.849066  0.770707
# DOGE-USD   0.652918  0.520217  0.682110  1.000000  0.711453  0.643346
# ETH-USD    0.743723  0.624863  0.849066  0.711453  1.000000  0.828622
# LINK-USD   0.736736  0.593451  0.770707  0.643346  0.828622  1.000000
# LTC-USD    0.784062  0.597034  0.830004  0.708849  0.835100  0.795647
# MATIC-USD  0.715046  0.606870  0.712874  0.668754  0.782532  0.741214
# NEAR-USD   0.478611  0.446794  0.482155  0.413300  0.517719  0.515245
# SOL-USD    0.644129  0.597073  0.606386  0.566104  0.697045  0.642086
# TRX-USD    0.671336  0.485927  0.653584  0.632875  0.681995  0.683755
# UNI-USD    0.152643  0.089168  0.076548  0.111342  0.048300  0.099561
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(25,25))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()
